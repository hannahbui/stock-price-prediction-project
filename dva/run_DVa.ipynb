# %% [markdown]
# - để metric evaluate với variable đã denormalize sau khi train để xem con số như thế nào

# %%
# !python --version
# Out:
# Python 3.11.11

# %% [markdown]
# ### Download code of Diffusion Variational Autoencoder from github repo into Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/RunVietDVa/dva"
# Out:
# /content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/RunVietDVa/dva

# %% [markdown]
# If you have already got the dva folder, do not run the below cell again (only run 1 time)

# %% [markdown]
# #### Download dependencies not through requirement.txt

# %%
# !pip install threadpoolctl

# %%
# !pip install gluonts

# %%
# !pip install lightning

# %% [markdown]
# ### Run the repo

# %% [markdown]
# Chuyển cột Close xuống cột cuối cùng của dataframe

# %%
import pandas as pd

# Đọc dữ liệu từ file hiện tại
file_path = '/content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/RunVietDVa/dva/data/apple_reordered/Apple_20120101_to_20241212.csv'  # Đường dẫn tới file dữ liệu hiện tại
df = pd.read_csv(file_path)

# Kiểm tra tên các cột trong dữ liệu
print("Các cột trong dữ liệu hiện tại:", df.columns)

# Sao chép dữ liệu của cột 'close'
close_column = df['close'].copy()

# Loại bỏ cột 'close' khỏi DataFrame
df = df.drop(columns=['close'])

# Thêm cột 'close' vào cuối DataFrame
df['close'] = close_column

# Lưu lại dữ liệu vào file cũ (file_path)
df.to_csv(file_path, index=False)

print(f"Dữ liệu đã được sao chép và cột 'close' đã được chuyển ra cuối cùng. Thay đổi đã được lưu trong file: {file_path}")

df
# Out:
# Các cột trong dữ liệu hiện tại: Index(['date', 'open', 'high', 'low', 'volume', 'close'], dtype='object')
# Dữ liệu đã được sao chép và cột 'close' đã được chuyển ra cuối cùng. Thay đổi đã được lưu trong file: /content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/RunVietDVa/dva/data/apple_reordered/Apple_20120101_to_20241212.csv
#             date        open        high         low     volume       close
# 0     2012-01-03   12.388996   12.427257   12.321814  302220800   12.333865
# 1     2012-01-04   12.455577   12.492935   12.330250  260022000   12.351941
# 2     2012-01-05   12.593857   12.609522   12.432377  271269600   12.501067
# 3     2012-01-06   12.725514   12.736059   12.629712  318292800   12.646281
# 4     2012-01-09   12.705328   12.886691   12.693880  394024400   12.818906
# ...          ...         ...         ...         ...        ...         ...
# ...

# %% [markdown]
# time_step = 10 (~ sequence_length: số ngày input)
#
# steps_out = 5
#
# loop_train = 10

# %%
# !python3 main.py --root_path data/apple_reordered --sequence_length 10
# Out:
# /usr/bin/python3
# 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Args in experiment:
# Namespace(root_path='data/apple_reordered', checkpoints='./checkpoints/', sequence_length=10, prediction_length=10, target_dim=1, input_dim=5, hidden_size=128, embedding_dimension=64, diff_steps=1000, dropout_rate=0.1, beta_schedule='linear', beta_start=0.0, beta_end=1.0, scale=0.1, arch_instance='res_mbconv', mult=1, num_layers=2, num_channels_enc=32, channel_mult=2, num_preprocess_blocks=1, num_preprocess_cells=3, groups_per_scale=2, num_postprocess_blocks=1, num_postprocess_cells=2, num_channels_dec=32, num_latent_per_group=8, num_workers=5, patience=3, itr=5, train_epochs=20, batch_size=16, learning_rate=0.0005, weight_decay=0.0, zeta=0.5, eta=1.0, use_gpu=True, gpu=0)
#
#
# Running on file Apple_20120101_to_20241212.csv (1/1)...
# Use GPU: cuda:0
# >>>>>>>start training : Apple_20120101_to_20241212.csv_tpapple_reordered_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 2260
# val 316
# test 642
# ...
